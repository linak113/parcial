# %%
import math
import random
1+1
# Out:
# 2

# %%
# Paso 1: Encontrar el número entero de 2 digitos que sea la edad del profesor.
# Paso 2: Borrar en la linea siguiente el simbolo "#", y escribir al lado del igual el número encontrado de 2 digitos.
# Paso 3: Se debe comentar el paso a paso de cómo se hizo para decifrar el código. En una nueva Linea de Código.
# Paso 4: Una vez solucionen y terminen la encriptación subir al Github el archivo con la Solución.
# Paso 5: Poner la solucion en la Décima pregunta y terminar el parcial.

#Nota una forma de hacerlo es utilizando el ciclo for o el ciclo while.

# Edad del profesor (Debes actualizar este valor según la edad del profesor para que el código se ejecute:) 
# edad_profesor =   # Ejemplo de edad, cámbiala por la edad del profesor.

def encriptar_url(url):
    # Función de encriptación
    encriptada = ""
    for i in range(len(url)):
        # Primer condicional
        encriptada += chr(ord(url[i]) + (i % 3) + 1)
    
    # URL encriptada para ser desencriptada después
    print(f"URL encriptada: {encriptada}")
    return encriptada

def desencriptar_url(url_encriptada, clave):
    # Verificar si la clave es igual a la edad del profesor
    if clave != edad_profesor:
        print("Clave incorrecta. No se puede desencriptar.")
        return None
    
    # Si la clave es correcta, se desencripta
    desencriptada = ""
    for i in range(len(url_encriptada)):
        # La operación inversa a la realizada en la encriptación
        desencriptada += chr(ord(url_encriptada[i]) - (i % 3) - 1)
    
    return desencriptada

# URL
url_original = "https://github.com/mattzarate333"
url_encriptada = encriptar_url(url_original)

# Para desencriptar el mensaje, el usuario debe introducir la edad del profesor como clave:
clave = int(input("Introduce la clave para desencriptar el mensaje: "))
url_desencriptada = desencriptar_url(url_encriptada, clave)

if url_desencriptada:
    print(f"URL desencriptada: {url_desencriptada}")


# Nota: Para Obtener 50 en el parcial las preguntas de Moodel deben estar perfectas.
# Decifrar el código antes de las 9:00am.
# Y dejar comentado en una nueva linea de código cómo encontró cada uno la solución.
# Out:
# URL encriptada: ivwqu=01jjvkvd1dqp0oduv}btdug645
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 43
#      41 # Para desencriptar el mensaje, el usuario debe introducir la edad del profesor como clave:
#      42 clave = int(input("Introduce la clave para desencriptar el mensaje: "))
# ---> 43 url_desencriptada = desencriptar_url(url_encriptada, clave)
#      45 if url_desencriptada:
#      46     print(f"URL desencriptada: {url_desencriptada}")
#
# Cell In[3], line 25, in desencriptar_url(url_encriptada, clave)
#      23 def desencriptar_url(url_encriptada, clave):
#      24     # Verificar si la clave es igual a la edad del profesor
# ---> 25     if clave != edad_profesor:
#      26         print("Clave incorrecta. No se puede desencriptar.")
#      27         return None
#
# NameError: name 'edad_profesor' is not defined

# %%
import random

# Paso 1: Encontrar el número entre 0 y 100 que sea la edad del profesor.
edad_del_profesor = random.randint(0, 30)

class Profesor:
    def capturar_url(self, url):
    
        return "Solución procesada"


profesor = Profesor()

# Usando un bucle for
for intento in range(40):
    if intento == edad_del_profesor:
        print(f"Adivinado con for: La edad del profesor es {intento}")
        break

# Usando un bucle while 
while intento <= 100:
    if intento == edad_del_profesor:
        print(f"Adivinado con while: La edad del profesor es {intento}")
        break
    intento += 1
# Out:
# Adivinado con for: La edad del profesor es 29
# Adivinado con while: La edad del profesor es 29
